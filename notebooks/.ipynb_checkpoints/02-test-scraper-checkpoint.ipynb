# %%
import pandas as pd
import requests
import time

from datetime import datetime

# %%
def call_bike_api():
    
    url = 'https://gbfs.capitalbikeshare.com/gbfs/en/free_bike_status.json'
    
    r = requests.get(url)
    j = r.json()
    b = j['data']['bikes']
    
    bikes = pd.json_normalize(b)
    bikes['timestamp'] = datetime.now().strftime("%H:%M:%S")
    
    return bikes

# %%
def call_station_status_api():
    
    url = 'https://gbfs.capitalbikeshare.com/gbfs/en/station_status.json'
    
    r = requests.get(url)
    j = r.json()
    b = j['data']['stations']
    
    bikes = pd.json_normalize(b)
    bikes['timestamp'] = datetime.now().strftime("%H:%M:%S")
    
    return stations

# %%
def scrape_bikes(interval):
    
    bike_data = pd.DataFrame()
    station_data = pd.DataFrame()
    timer = 0
    
    while timer < 30:
        
        current_bikes = call_bike_api()
        current_stations = call_station_api()
        
        bike_data = pd.concat((bike_data, current_bikes))
        station_data = pd.concat((station_data, current_stations))
        
        bike_data.to_csv('../raw_data/bike_data.csv')
        station_data.to_csv('../raw_data/station_data.csv')
        
        timer = timer + interval
        time.sleep(interval)

# %%
scrape_bikes(10)

# %%
test
# Out:
#            lon  is_disabled           type                           bike_id  \
# 0   -76.924386            0  electric_bike  c7ef87165778006cf0f66a39f3533c47
# 1   -76.968681            0  electric_bike  f132ef3760e67f0f12e6294684f721c6
# 2   -77.028428            0  electric_bike  212ef3ab9baee354bba2deadc7e74fd7
# 3   -77.008976            0  electric_bike  39e788db770bd87630449ce4754adbd4
# 4   -77.007594            0  electric_bike  fa0ce97edf6dab1af8cf871fe1d1301f
# ..         ...          ...            ...                               ...
# 190 -77.008551            0  electric_bike  7e7585b436504752ee879282d235ba3a
# 191 -77.040059            0  electric_bike  3b73d5e182fad403e88afe4ff7aae0cf
# 192 -76.984838            0  electric_bike  fa7c5828c02ea3f761c1f7b69710dc3c
# 193 -77.086053            0  electric_bike  ea1c91608d136b866fe7ea4aebd78ae8
# 194 -77.064652            0  electric_bike  d23f8b5da417bbfbf1889193177293ab
#
# ...

# %% [raw]
# def get_data():
#
#     bike_url = 'https://gbfs.capitalbikeshare.com/gbfs/en/free_bike_status.json'
#     station_url = 'https://gbfs.capitalbikeshare.com/gbfs/en/station_status.json'
#
#     bike_request = requests.get(bike_url)
#     station_request = requests.get(station_url)
#
#     bike_json = bike_request.json()
#     station_json = station_request.json()

# %%
r = requests.get('https://gbfs.capitalbikeshare.com/gbfs/en/free_bike_status.json')
j = r.json()
b = j['data']['bikes']

bikes = pd.json_normalize(b)

# %%
j
# Out:
# {'data': {'bikes': [{'bike_id': '416c3fd0dd66b7978fd6198adb1908d7',
#     'is_reserved': 0,
#     'is_disabled': 0,
#     'type': 'electric_bike',
#     'name': '416c3fd0dd66b7978fd6198adb1908d7',
#     'lon': -76.9956575,
#     'lat': 38.9786495,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'}},
#    {'bike_id': '89a19933041ba91547509be0c25e197b',
#     'is_reserved': 0,
#     'is_disabled': 0,
#     'type': 'electric_bike',
#     'name': '89a19933041ba91547509be0c25e197b',
#     'lon': -76.97393633333333,
#     'lat': 38.89810166666667,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'}},
#    {'bike_id': 'bd39f079631025f4e5e00a0a073e430c',
#     'is_reserved': 0,
#     'is_disabled': 0,
#     'type': 'electric_bike',
#     'name': 'bd39f079631025f4e5e00a0a073e430c',
#     'lon': -76.957412,
#     'lat': 38.885065166666664,
# ...

# %%
bikes
# Out:
#                               bike_id  is_reserved  is_disabled  \
# 0    416c3fd0dd66b7978fd6198adb1908d7            0            0
# 1    89a19933041ba91547509be0c25e197b            0            0
# 2    bd39f079631025f4e5e00a0a073e430c            0            0
# 3    63c414ac07a4cc90b4c9e863661c5b9c            0            0
# 4    cdec57bf7c23f21321da57fa735cee07            0            0
# ..                                ...          ...          ...
# 189  4d8cf337650efafa19b29a961db086e3            0            0
# 190  ec184d501d562abdd684398577fe1ea8            0            0
# 191  705778ed2efbcfb54d06a97ed60852db            0            0
# 192  ec7e09b5b553885af9336340303f02fc            0            0
# 193  aed3f7daebb210c16af12ee611f0224e            0            0
#
#               type                              name        lon        lat  \
# 0    electric_bike  416c3fd0dd66b7978fd6198adb1908d7 -76.995657  38.978650
# ...

# %%
bikes.groupby('type').size()
# Out:
# type
# electric_bike    194
# dtype: int64
